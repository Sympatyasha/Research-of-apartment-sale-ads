# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Николай, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# Ряд вопросов и затруднений в ходе проекта, нужна ваша помощь
# https://docs.google.com/document/d/1WrWmVRUOzChc196-G7uZTnCh_TglAe1YwWYubG2V5Zc/edit

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Попробую ответить на твои вопросы.
#
# 1. Все же целесообразней с такими вопросами в первую очередь сходить к преподавателю по проектам. Он гораздо быстрей, а главное подробней ответит на подобные вопросы.
#
# 2.
#
# * locality_name - доля пропусков менее 5% и мы вполне можем их удалить.
#
# * floors_total - аналогично.
#
# * Картография - картографию я бы не трогал, тк вероятно расстояние автоматически не подсчиталось до объектов, или может там нет парков прудов и прочего. Как вариант конечно можно было провести группировку по населенному пункту с измерением среднего показателя, далее заполнить соответствующим значением, но не думаю, что мы бы много записей спасли
#
# living_area, kitchen_area, ceiling_height - концепция обучения такая, что сначала необходимо выполнить задание правильно, или не правильно, а затем получить оценочный комментарий.
#
# 3. data['floors_total’] имеет тип float, на int исправить не получается (скорее всего из-за nan значений, не уверен) - ответ я дал выше.
#
# 4. Есть 'Мурино' а есть  'поселок Мурино' - это одно и то же место? если да, то нужно ли искать подобные кейсы вручную или есть команда для устранения таких дубликатов - здесь поискать ответ стоит самому.
#
# 5. Обработка аномалий - можно обработать до исследовательской части, а можно во время, но, лучше придерживаться шагов ТЗ.
#
# 6. В целом, твоя функция выполняет задачу по нахождению и удалению выбросов с использованием межквартильного диапазона `(IQR)` и построению `boxplot'ов` до и после очистки данных. Однако, есть несколько моментов, которые можно улучшить:
#
# * Улучшение читаемости кода:
#
#   * Хорошей практикой является оформление кода в соответствии с PEP 8. Ты можешь добавить пустые строки для лучшей читаемости между блоками кода.
#   * Добавь комментарии к коду, чтобы пояснить его логику. Например, почему используется 1.5 * IQR для определения границ выбросов.
#
# * Вывод границ выбросов:
#
#   * Можешь добавить вывод границ выбросов (lower_bound и upper_bound) в консоль, чтобы пользователь мог видеть, какие значения считаются выбросами.
#
#
# * Обработка случая, когда IQR равен 0:
#
#   * При нулевом IQR формула для границ выбросов может привести к ошибке. Можешь добавить проверку и обработку этого случая.
#
#
# * Улучшение функциональности:
#
#   * Можешь добавить параметр для выбора, убирать ли выбросы или создавать новый DataFrame без них.
#
#   * Можешь добавить возможность возвращать не только очищенные данные, но и информацию о том, сколько выбросов было удалено.
#
# **Вот пример с учетом указанных рекомендаций:**
#
#     def anomaly_clear(data, column, remove_outliers=True):
#         """
#         Удаляет выбросы из столбца column DataFrame data, используя межквартильный диапазон (IQR).
#
#         :param data: DataFrame с данными
#         :param column: Название столбца, в котором необходимо удалить выбросы
#         :param remove_outliers: Флаг, указывающий, следует ли удалять выбросы (по умолчанию True)
#         :return: Очищенный DataFrame (если remove_outliers=True) или информация о количестве удаленных выбросов
#         """
#         print(f"Исходный boxplot для {column}")
#         plt.figure(figsize=(6, 4))
#         data.boxplot(column=column)
#         plt.show()
#
#         Q1 = data[column].quantile(0.25)
#         Q3 = data[column].quantile(0.75)
#         IQR = Q3 - Q1
#
#         # Обработка случая, когда IQR равен 0
#         if IQR == 0:
#             print(f"IQR для {column} равен 0. Невозможно определить границы выбросов.")
#             return data
#
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#
#         print(f"Границы выбросов для {column}: [{lower_bound}, {upper_bound}]")
#
#         if remove_outliers:
#             filtered_data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
#             print(f"Boxplot для {column} после удаления выбросов")
#             filtered_data.boxplot(column=column)
#             plt.show()
#             return filtered_data
#         else:
#             outliers_count = len(data[(data[column] < lower_bound) | (data[column] > upper_bound)])
#             print(f"Количество выбросов в {column}: {outliers_count}")
#             return f"Выбросы не удалены. Их количество: {outliers_count}"
#
# Пример использования:
#
# `cleaned_data = anomaly_clear(my_data, 'my_column')`
#
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# <h4>Импорт данных в датасет

# %%
import pandas as pd

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Хорошей практикой является разделение импорта библиотек и выполнения основной логики кода, такой как загрузка данных, для лучшей читаемости и структурированности. Такое разделение помогает сделать код более понятным и удобным для других разработчиков или коллег, которые будут просматривать или использовать твой код.
#
# Разделение импортов и загрузки данных — это общепринятая хорошая практика, которой рекомендуется следовать
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#   Исправил, спасибо за комментарий !
# </div>

# %% [markdown]
# <h4>Просмотр содержимого датасета

# %%
display(data)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также я бы посоветовал использовать `display()` вместо `print()` для более аккуратного вывода таблиц.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#   Исправил, спасибо за комментарий !
# </div>

# %% [markdown]
# <h4>Изучение колонок, их типов данных и количество ненулевых значений

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <h4>Построение гистограммы для всех числовых столбцов таблицы

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#   Исправил, спасибо за комментарий !
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Здесь у нас заканчивается вводная часть ознакомления с данными. Основная информация получена. Было бы неплохо также привести небольшое заключение по объему данных и основных ошибках, которые уже были обнаружены на этой стадии (типы данных, пропуски, названия колонок и др).
# </div>

# %% [markdown]
# На основе начального анализа набора данных, который содержит объявления о недвижимости, можно сделать следующие выводы:
#
# - **Размер и структура набора данных**: Набор данных включает 23 699 записей и 22 столбца, что указывает на значительный объем данных для анализа.
#
# - **Типы данных**:
#   - В наборе данных присутствует смесь числовых (`int64` и `float64`), булевых (`bool`) и объектных (`object`) типов данных.
#   - Столбец `first_day_exposition`, который, по-видимому, представляет даты, неправильно типизирован как `object` и должен быть преобразован в `datetime` для корректного анализа временных рядов.
#   - Столбец `is_apartment`, вероятно, предназначенный для указания, является ли объявление апартаментами, в настоящее время типизирован как `object`. Это указывает на то, что он может содержать значения, которые не являются строго булевыми (`True`/`False`), и может потребовать очистки.
#
# - **Пропущенные значения**: Несколько столбцов имеют значительное количество пропущенных значений, что может повлиять на анализ:
#   - `ceiling_height`, `floors_total`, `living_area`, `kitchen_area`, `balcony`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest` и `days_exposition` все имеют пропущенные записи в разной степени.
#   - В частности, `is_apartment`, `parks_nearest` и `ponds_nearest` имеют большую долю пропущенных значений, что может указывать на то, что эта информация не всегда доступна или не была собрана для всех объявлений.
#
# - **Названия столбцов**: Названия столбцов ясные и описательные, указывают, что представляет каждый столбец без видимых опечаток или несоответствий.
#
# - **Начальные ошибки и соображения**:
#   - **Отсутствующие данные**: Обработка пропущенных значений, либо путем импутации, либо удаления, в зависимости от контекста анализа, будет критически важна.
#   - **Исправление типов данных**: Преобразование `first_day_exposition` в `datetime` и потенциальная очистка `is_apartment` для обеспечения его булевого типа являются немедленными шагами для улучшения качества данных.
#   - **Распределение переменных**: Гистограммы показывают распределение числовых переменных, указывая на широкий диапазон значений по различным характеристикам, таким как `total_area`, `last_price` и `days_exposition`. Это указывает на то, что масштабирование или нормализация могут быть полезны для определенных анализов.
#
# В целом, набор данных представляет хорошую основу для анализа рынка недвижимости с учетом необходимости очистки и предварительной обработки для устранения пропущенных значений и неправильных типов данных.

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# <h4>Найдем столбцы, которые имеют пропуски (значения NaN)

# %%
data.isna().sum().sort_values()
# Out:
# total_images                0
# open_plan                   0
# floor                       0
# rooms                       0
# studio                      0
# total_area                  0
# last_price                  0
# first_day_exposition        0
# locality_name              49
# floors_total               86
# living_area              1903
# kitchen_area             2278
# days_exposition          3181
# ponds_around3000         5518
# parks_around3000         5518
# cityCenters_nearest      5519
# airports_nearest         5542
# ceiling_height           9195
# balcony                 11519
# ponds_nearest           14589
# parks_nearest           15620
# is_apartment            20924
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также, помимо абсолютных значений мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков, например: `pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')`
#
#
# </div>

# %%
pd.DataFrame(round(data.isna().mean()*100,1).sort_values(ascending=False)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_c3d01_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c3d01_row1_col0{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_c3d01_row2_col0{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_c3d01_row3_col0{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_c3d01_row4_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_c3d01_row5_col0,#T_c3d01_row6_col0,#T_c3d01_row7_col0,#T_c3d01_row8_col0{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_c3d01_row9_col0{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_c3d01_row10_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_c3d01_row11_col0{
#             background-color:  #5673e0;
# ...

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Очень понравилось ваше предложение, дополнил его тем, что отсортировал доли по убыванию,
#     чтобы было легче их сравнить
#
# Благодарю!
# </div>

# %% [markdown]
# <h4>Устранение пропусков (значения NaN)

# %% [markdown]
# days_exposition — сколько дней было размещено объявление. можно предположить, что
# пропуск вызван отсутствием информации о дне публикации - можем заполнить нулями. Но пока что закомментируем, чтобы не отбрасывать записи при подсчете показателей

# %%
#data['days_exposition'] = data['days_exposition'].fillna(0)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Дни экспозиции я бы вообще не заполнял, тк признак далее используется, а твое заполнение по сути обязует тебя отбрасывать записи при подсчете показателей
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#   Если не заполнить days_exposition то на этапе "Исправление некорректных типов данных столбцов" не получится исправить тип данных
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Есть вариант использовать параметр `errors='coerce'` с функцией `pd.to_numeric()`, чтобы преобразовать данные в числовой тип, принудительно преобразуя неподходящие значения (включая NaN) в NaN, но уже в числовом формате. Однако, прямое применение `errors='coerce'` не позволит преобразовать данные в целочисленный формат без появления дробной части, так как NaN несовместим с целочисленными типами до введения типа Int64 в pandas, который поддерживает NaN.
#
# Можно использовать `pd.to_numeric()` для преобразования данных и затем изменить тип данных на целочисленный, сохраняя при этом NaN для обозначения пропущенных значений. Это можно сделать это в два шага:
#
# * Применить `pd.to_numeric(`) с `errors='coerce'`, чтобы преобразовать столбец в числовой формат, автоматически преобразовывая неподходящие или пропущенные значения в NaN.
#
# * Затем преобразовать результат в тип Int64, чтобы обозначить целочисленные значения с возможностью использовать NaN.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
#  Исправил, спасибо!
# Добавил в начало части "2.4  Исправление некорректных типов данных столбцов"
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Прошу тебя все выводы перенести в отдельные ячейки Markdown.
# </div>

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %% [markdown]
# balcony — число балконов. при отсутствии балкона могло быть оставлено пустое значение, поэтому разумно заполнить нулевыми значениями

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, люди не заполняют "не выгодные" для продажи квартиры характеристики.
# </div>

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %% [markdown]
# locality_name  - 49 строк с пропусками - относительно незначительное количество, более того,
# данные пропуски невозможно заполнить каким либо значением (название будет некорректно придумывать самим), поэтому удаляем

# %%
data.dropna(subset=['locality_name'], inplace=True)

# %%
# 86 строк с пропусками - незначительное количество, более того, 
# ...
data.dropna(subset=['floors_total'], inplace=True)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Согласен
# </div>

# %%
#
(data['living_area'] / data['total_area']).mean() 
data['living_area'] = data['living_area'].fillna(data['total_area'] * (data['living_area'] / data['total_area']).mean())

# %% [markdown]
# Посмотрим результаты обработки

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Также мы можем обработать столбец ceiling_height. Высоту можно заполнить медианой с учетом группировки по локации или расстоянию до центра в км, логично что в большинстве случаев потолки в исторической застройке выше. Либо же как вариант заполнить медианой.
# </div>

# %%
# Сначала создаем таблицу с медианными значениями
median_ceiling_height_by_location = data.groupby('locality_name')['ceiling_height'].median().reset_index(name='ceiling_height_median')

# Объединяем исходные данные с таблицей медианных значений
data_filled_by_location_corrected = pd.merge(data, median_ceiling_height_by_location, on='locality_name', how='left')

# Заполняем пропуски в ceiling_height, используя медианные значения по локации
data_filled_by_location_corrected['ceiling_height'].fillna(data_filled_by_location_corrected['ceiling_height_median'], inplace=True)

# Повторяем процедуру для группировки по расстоянию до центра
# Создаем группы по расстоянию до центра
data['cityCenters_nearest_group'] = pd.cut(data['cityCenters_nearest'], bins=10)
median_ceiling_height_by_distance = data.groupby('cityCenters_nearest_group')['ceiling_height'].median().reset_index(name='ceiling_height_median_by_distance')

# Объединяем исходные данные с таблицей медианных значений по расстоянию
data_filled_by_distance_corrected = pd.merge(data, median_ceiling_height_by_distance, on='cityCenters_nearest_group', how='left')

# Заполняем пропуски в ceiling_height, используя медианные значения по расстоянию до центра
data_filled_by_distance_corrected['ceiling_height'].fillna(data_filled_by_distance_corrected['ceiling_height_median_by_distance'], inplace=True)

# Проверим результаты заполнения: сколько осталось пропусков после каждого из подходов
missing_after_location_corrected = data_filled_by_location_corrected['ceiling_height'].isna().sum()
missing_after_distance_corrected = data_filled_by_distance_corrected['ceiling_height'].isna().sum()

print("Сколько пропусков после локационного метода ", missing_after_location_corrected)
print("Сколько пропусков после метода по расстоянию до центра ", missing_after_distance_corrected)
# Out:
# Сколько пропусков после локационного метода  120
# Сколько пропусков после метода по расстоянию до центра  2560

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data = data_filled_by_location_corrected

# %% [markdown]
# <h4>Изучим информацию о типах данных столбцов

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23564
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           23565 non-null  int64
#  1   last_price             23565 non-null  float64
#  2   total_area             23565 non-null  float64
#  3   first_day_exposition   23565 non-null  object
#  4   rooms                  23565 non-null  int64
#  5   ceiling_height         23445 non-null  float64
#  6   floors_total           23565 non-null  float64
#  7   living_area            23565 non-null  float64
#  8   floor                  23565 non-null  int64
#  9   is_apartment           23565 non-null  bool
#  10  studio                 23565 non-null  bool
#  11  open_plan              23565 non-null  bool
#  12  kitchen_area           23565 non-null  float64
#  13  balcony                23565 non-null  float64
# ...

# %% [markdown]
# <h4>Исправление некорректных типов данных столбцов

# %%
# Количество дней - всегда целое число, меняем тип столбца на int

# Преобразуем столбец в числовой формат, автоматически преобразуя неподходящие или пропущенные значения в NaN
data['days_exposition'] = pd.to_numeric('days_exposition', errors='coerce')

# Затем преобразуем результат в тип Int64
data['days_exposition'] = data['days_exposition'].astype('Int64')

# %%
#изменяем тип столбца is_apartment, так как принимаемые значения - True/False
#data['is_apartment'] = data['is_apartment'].astype('bool') после заполнения пропусков уже исправилось

#количество балконов - всегда целое число, меняем тип столбца на int
data['balcony'] = data['balcony'].astype('int')

#столбец с датой и временем публикации -> меняем на тип datetime
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y%m%d %H:%M:%S.')


#количество этажей - всегда целое число, меняем тип столбца на int
data['floors_total'] = data['floors_total'].astype('int')

#проверяем изменения
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23564
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           23565 non-null  int64
#  1   last_price             23565 non-null  float64
#  2   total_area             23565 non-null  float64
#  3   first_day_exposition   23565 non-null  datetime64[ns]
#  4   rooms                  23565 non-null  int64
#  5   ceiling_height         23445 non-null  float64
#  6   floors_total           23565 non-null  int64
#  7   living_area            23565 non-null  float64
#  8   floor                  23565 non-null  int64
#  9   is_apartment           23565 non-null  bool
#  10  studio                 23565 non-null  bool
#  11  open_plan              23565 non-null  bool
#  12  kitchen_area           23565 non-null  float64
#  13  balcony                23565 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на тип данных в floors_total, вряд ли он должен быть дробным.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#  Исправил, спасибо!
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# <h4>Устранение неявных дубликатов в названиях населённых пунктов.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
print(len(data['locality_name'].unique()))
data['locality_name'] = data['locality_name'].str.replace('посёлок','поселок')
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')
print(len(data['locality_name'].unique()))
data['locality_name'].sort_values().unique()
# Out:
# 364
# 323
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
# ...

# %%
print(data['locality_name'].duplicated())
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 23560     True
# 23561     True
# 23562     True
# 23563     True
# 23564     True
# Name: locality_name, Length: 23565, dtype: bool

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
# <h4>Обработка редких и выбивающихся значений (аномалий)

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово',
#        'поселок Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.   ,   1.2  ,   1.75 ,   2.   ,   2.2  ,   2.25 ,   2.3  ,
#          2.34 ,   2.4  ,   2.45 ,   2.46 ,   2.47 ,   2.48 ,   2.49 ,
#          2.5  ,   2.51 ,   2.515,   2.52 ,   2.525,   2.53 ,   2.54 ,
#          2.55 ,   2.555,   2.56 ,   2.56 ,   2.57 ,   2.575,   2.58 ,
#          2.59 ,   2.6  ,   2.6  ,   2.61 ,   2.615,   2.62 ,   2.625,
#          2.63 ,   2.64 ,   2.65 ,   2.65 ,   2.66 ,   2.67 ,   2.675,
#          2.68 ,   2.69 ,   2.7  ,   2.71 ,   2.72 ,   2.725,   2.73 ,
#          2.74 ,   2.75 ,   2.76 ,   2.77 ,   2.78 ,   2.79 ,   2.8  ,
#          2.81 ,   2.82 ,   2.83 ,   2.84 ,   2.85 ,   2.86 ,   2.87 ,
#          2.88 ,   2.89 ,   2.9  ,   2.91 ,   2.92 ,   2.93 ,   2.94 ,
#          2.95 ,   2.96 ,   2.97 ,   2.98 ,   2.99 ,   3.   ,   3.01 ,
#          3.02 ,   3.03 ,   3.04 ,   3.05 ,   3.06 ,   3.07 ,   3.08 ,
#          3.09 ,   3.1  ,   3.11 ,   3.12 ,   3.13 ,   3.14 ,   3.15 ,
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23564
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           23565 non-null  int64
#  1   last_price             23565 non-null  float64
#  2   total_area             23565 non-null  float64
#  3   first_day_exposition   23565 non-null  datetime64[ns]
#  4   rooms                  23565 non-null  int64
#  5   ceiling_height         23445 non-null  float64
#  6   floors_total           23565 non-null  int64
#  7   living_area            23565 non-null  float64
#  8   floor                  23565 non-null  int64
#  9   is_apartment           23565 non-null  bool
#  10  studio                 23565 non-null  bool
#  11  open_plan              23565 non-null  bool
#  12  kitchen_area           23565 non-null  float64
#  13  balcony                23565 non-null  int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


'''
удаление аномальных значений высоты потолка
закомментировал потому что в 4 шаге нужно: 

в столбце ceiling_height может быть указана высота потолков 25 м и 32 м.
Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м.


plt.figure(figsize=(6,4))
data.boxplot(column=['ceiling_height'])
plt.show()
Q1 = data['ceiling_height'].quantile(0.25)
Q3 = data['ceiling_height'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
#how_much_deleted = data[(data['ceiling_height'] < lower_bound) | (data['ceiling_height'] > upper_bound)]
data = data[(data['ceiling_height'] > lower_bound) & (data['ceiling_height'] < upper_bound)]
plt.figure(figsize=(6,4))
data.boxplot(column=['ceiling_height'])
plt.show()
'''
# Out:
# "\nудаление аномальных значений высоты потолка\nзакомментировал потому что в 4 шаге нужно: \n\nв столбце ceiling_height может быть указана высота потолков 25 м и 32 м.\nЛогично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м.\n\n\nplt.figure(figsize=(6,4))\ndata.boxplot(column=['ceiling_height'])\nplt.show()\nQ1 = data['ceiling_height'].quantile(0.25)\nQ3 = data['ceiling_height'].quantile(0.75)\nIQR = Q3 - Q1\nlower_bound = Q1 - 1.5 * IQR\nupper_bound = Q3 + 1.5 * IQR\n#how_much_deleted = data[(data['ceiling_height'] < lower_bound) | (data['ceiling_height'] > upper_bound)]\ndata = data[(data['ceiling_height'] > lower_bound) & (data['ceiling_height'] < upper_bound)]\nplt.figure(figsize=(6,4))\ndata.boxplot(column=['ceiling_height'])\nplt.show()\n"

# %%
data[data['floor'] > data['floors_total']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, ceiling_height_median]
# Index: []
#
# [0 rows x 23 columns]

# %%
data['total_area'].sort_values().head(20)
# Out:
# 19795    12.00
# 17859    13.00
# 19437    13.00
# 19698    13.00
# 19449    13.20
# 19533    14.00
# 11972    15.00
# 16852    15.00
# 8843     15.50
# 9367     16.00
# 10155    17.00
# 712      17.00
# 22231    17.20
# 9112     17.60
# 21678    17.78
# 12922    18.00
# 20598    18.00
# 6052     18.00
# 19204    18.00
# 4521     18.00
# Name: total_area, dtype: float64

# %%
loc_stat = pd.pivot_table(data, index=['locality_name'], values='floors_total', aggfunc='mean').reset_index()
loc_stat
# Out:
#             locality_name  floors_total
# 0            Бокситогорск      4.187500
# 1                Волосово      4.555556
# 2                  Волхов      4.855856
# 3              Всеволожск      8.391960
# 4                  Выборг      5.873418
# ..                    ...           ...
# 318         село Путилово      4.000000
# 319      село Рождествено      3.000000
# 320  село Русско-Высоцкое      7.222222
# 321    село Старая Ладога      2.500000
# 322              село Шум      2.000000
#
# [323 rows x 2 columns]

# %%
data.loc[data['floors_total'].isna()]
data['floors_total'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# total_images                 0
# last_price                   0
# total_area                   0
# first_day_exposition         0
# rooms                        0
# ceiling_height             120
# floors_total                 0
# living_area                  0
# floor                        0
# is_apartment                 0
# studio                       0
# open_plan                    0
# kitchen_area                 0
# balcony                      0
# locality_name                0
# airports_nearest          5524
# cityCenters_nearest       5501
# parks_around3000          5500
# parks_nearest            15535
# ponds_around3000          5500
# ponds_nearest            14529
# days_exposition          23565
# ceiling_height_median      120
# dtype: int64

# %%
data[data['floor'] > data['floors_total']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, ceiling_height_median]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# В целом раздел выполнен не плохо.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Но, есть замечания:
#
# * Отсутствует проверка явных дубликатов в датасете, а это основа предобработки данных.
#
# * Отсутствует промежуточный вывод о проделанной работе в разделе.
#
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# Проверяем на явные дубликаты

# %%
duplicates = data.duplicated().sum()

duplicates
# Out:
# 0

# %% [markdown]
# В датасете не обнаружено явных дубликатов. Это означает, что каждая строка в наборе данных уникальна.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# Цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);

# %%
data['square_meter_price'] = data['last_price'] / data['total_area']
data['square_meter_price'] = data['square_meter_price'].round(decimals=2) 
data['square_meter_price']
# Out:
# 0        120370.37
# 1         82920.79
# 2         92785.71
# 3        408176.10
# 4        100000.00
#            ...
# 23560     72490.85
# 23561     52542.37
# 23562     44091.71
# 23563    149511.40
# 23564     41795.67
# Name: square_meter_price, Length: 23565, dtype: float64

# %% [markdown]
# День недели, месяц и год публикации объявления

# %%
data['day_publication'] = data['first_day_exposition'].dt.weekday
data['month_publication'] = data['first_day_exposition'].dt.month
data['year_publication'] = data['first_day_exposition'].dt.year
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0           2.700            16    51.000000      8         False  ...
# 1           2.615            11    18.600000      1         False  ...
# 2           2.700             5    34.300000      4         False  ...
# 3           2.700            14    89.825011      9         False  ...
# 4           3.030            14    32.000000     13         False  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# На будущее: часто датафреймы содержат данные за разные годы. Чтобы корректно обработать месяцы и не объединить их из разных годов, можно рассмотреть такой метод `astype('datetime64[M]')`. При использовании этого метода не придется ссылаться на `pd.DatetimeIndex`.
#
# Рекомендую ознакомиться с этими материалами:
#
# [Работа с датами в Python]( https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/)
#
# [Извлечение часов, минут и секунд из numpy datetime64](https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64)
#
# Попробуй использовать этот метод, когда агализируешь динамику по неделям, месяцам или годам.
#
# Пример применения:
#
#
# `df['first_day_exposition'].dt.date # конвертация в формат даты
# df['first_day_exposition'].astype('datetime64[M]')`
#
# Если даты в датафрейме из разных годов, то после преобразования месяцы будут отображаться как первый день каждого месяца, например '2019-05-01'.
#
# </div>

# %% [markdown]
# Тип этажа квартиры (значения — «‎первый», «последний», «другой»);

# %%
def floortype(floors):
    if floors['floor'] == 1:
        return 'первый'
    if floors['floor'] == floors['floors_total']:
        return 'последний'
    return 'другой'
def floortypedigit(floors):
    if floors['floor'] == 1:
        return 1
    if floors['floor'] == floors['floors_total']:
        return 3
    return 2
data['floor_type'] = data.apply(floortype, axis=1)
data['floor_type_digit'] = data.apply(floortypedigit, axis=1)
data['floor_type'].head(20)
#data['floor_type_digit'].head(20)
# Out:
# 0        другой
# 1        первый
# 2        другой
# 3        другой
# 4        другой
# 5        другой
# 6        другой
# 7        другой
# 8        другой
# 9        другой
# 10       другой
# 11       другой
# 12    последний
# 13    последний
# 14       первый
# 15       другой
# 16       первый
# 17       другой
# 18       другой
# 19       другой
# Name: floor_type, dtype: object

# %% [markdown]
# Расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %%
data['cityCenters_nearest_km'] = data['cityCenters_nearest'] / 1000
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].round()
data['cityCenters_nearest_km'].head() 
#  ВОПРОС РЕВЬЮЕРУ нужно ли переводить в int?
# Out:
# 0    16.0
# 1    19.0
# 2    14.0
# 3     7.0
# 4     8.0
# Name: cityCenters_nearest_km, dtype: float64

# %%
#data['cityCenters_nearest_km'].astype(int)
#data['cityCenters_nearest']

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Желательно, так будет корректней.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#  Не получается из-за NaN значений
#      Cannot convert non-finite values (NA or inf) to integer
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Проблема с преобразованием data['cityCenters_nearest_km'] в целочисленный тип из-за NaN значений довольно распространена. Когда ты пытаешься использовать .astype(int) на столбце с NaN, Python не знает, как обработать эти пропущенные значения, потому что NaN невозможно прямо преобразовать в целое число.
#
# Чтобы решить эту задачу, тебе нужно использовать тип Int64 вместо int. Тип Int64 — это специальный целочисленный тип в pandas, который позволяет содержать NaN значения. Вот как это сделать:
#
#
#     data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].astype('Int64')
#
#
# Не забудь, что после округления ты должен присвоить результат обратно в твой DataFrame, что ты и сделал правильно. Только вот при преобразовании типа данных нужно также сохранить изменения:
#
#
#     data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].round()
#     data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].astype('Int64')
#
#
# Теперь у тебя data['cityCenters_nearest_km'] должен быть успешно преобразован в целочисленный формат, даже если в нем есть NaN значения. Это позволит тебе работать с этим столбцом как с целыми числами, сохраняя информацию о пропущенных данных.
#
# Надеюсь, это поможет. Попробуй, пожалуйста, применить и я буду ждать твой проект на повторное ревью.
# </div>

# %%
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].round()
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].astype('Int64')

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
# Исправил, спасибо!
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Проверка нововведений

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0           2.700            16    51.000000      8         False  ...
# 1           2.615            11    18.600000      1         False  ...
# 2           2.700             5    34.300000      4         False  ...
# 3           2.700            14    89.825011      9         False  ...
# 4           3.030            14    32.000000     13         False  ...
#
#    ponds_nearest  days_exposition  ceiling_height_median  square_meter_price  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично! Можем приступать к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
data.size
# Out:
# 706950

# %% [markdown]
# def anomaly_clear(data, column, remove_outliers=True):
#     """
#     Удаляет выбросы из столбца column DataFrame data, используя межквартильный диапазон (IQR).
#
#     :param data: DataFrame с данными
#     :param column: Название столбца, в котором необходимо удалить выбросы
#     :param remove_outliers: Флаг, указывающий, следует ли удалять выбросы (по умолчанию True)
#     :return: Очищенный DataFrame (если remove_outliers=True) или информация о количестве удаленных выбросов
#     """
#     print(f"Исходный boxplot для {column}")
#     plt.figure(figsize=(6, 4))
#     data.boxplot(column=column)
#     plt.show()
#
#     Q1 = data[column].quantile(0.25)
#     Q3 = data[column].quantile(0.75)
#     IQR = Q3 - Q1
#
#     # Обработка случая, когда IQR равен 0
#     if IQR == 0:
#         print(f"IQR для {column} равен 0. Невозможно определить границы выбросов.")
#         return data
#
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#
#     print(f"Границы выбросов для {column}: [{lower_bound}, {upper_bound}]")
#
#     if remove_outliers:
#         filtered_data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
#         print(f"Boxplot для {column} после удаления выбросов")
#         filtered_data.boxplot(column=column)
#         plt.show()
#         return filtered_data
#     else:
#         outliers_count = len(data[(data[column] < lower_bound) | (data[column] > upper_bound)])
#         print(f"Количество выбросов в {column}: {outliers_count}")
#         return f"Выбросы не удалены. Их количество: {outliers_count}"

# %% [markdown]
# def anomaly_clear(data, column, max_outliers_percentage=5):
#     """
#     Удаляет выбросы из столбца column DataFrame data, используя межквартильный диапазон (IQR),
#     но не более заданного процента от всех данных.
#
#     :param data: DataFrame с данными
#     :param column: Название столбца, в котором необходимо удалить выбросы
#     :param max_outliers_percentage: Максимальный процент данных для удаления как выбросы
#     :return: Очищенный DataFrame
#     """
#     print(f"Исходный boxplot для {column}")
#     plt.figure(figsize=(6, 4))
#     data.boxplot(column=column)
#     plt.show()
#
#     Q1 = data[column].quantile(0.25)
#     Q3 = data[column].quantile(0.75)
#     IQR = Q3 - Q1
#
#     # Обработка случая, когда IQR равен 0
#     if IQR == 0:
#         print(f"IQR для {column} равен 0. Невозможно определить границы выбросов.")
#         return data
#
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#
#     print(f"Границы выбросов для {column}: [{lower_bound}, {upper_bound}]")
#
#     # Определение количества выбросов
#     outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
#     outliers_percentage = len(outliers) / len(data) * 100
#
#     # Удаление выбросов, если они составляют менее max_outliers_percentage от всех данных
#     if outliers_percentage > max_outliers_percentage:
#         print(f"Выбросы составляют {outliers_percentage}% от всех данных, что больше допустимого порога {max_outliers_percentage}%.")
#         print("Удаляем не более допустимого процента данных как выбросы.")
#         # Удаляем только ту часть данных, которая не превышает max_outliers_percentage
#         num_outliers_to_remove = int(len(data) * max_outliers_percentage / 100)
#         filtered_data = data.drop(outliers.nsmallest(num_outliers_to_remove, column).index)
#     else:
#         filtered_data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
#         print(f"Удалено {len(outliers)} записей из столбца {column}.")
#
#     print(f"Boxplot для {column} после удаления выбросов")
#     filtered_data.boxplot(column=column)
#     plt.show()
#     return filtered_data

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
#  Попробовал изменить функцию, чтобы уменьшить размер удаляемых данных (чтобы не удалялась половина). Если это неправильный подход, то вынужден сказать, что иных решений и даже идей у меня нет и нужен в таком случае ответ\разбор от ревьюера, так как все идеи по данному проекту, которые мог исправить, уже исправил
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# ✍
# Давай попробуем разобраться.
#
# Твоя идея уменьшить влияние удаления выбросов на датасет путем ограничения максимального процента удаляемых данных интересна, но есть несколько моментов, которые могут помочь улучшить твой подход.
#
# **Во-первых**, важно понимать, что удаление значительной части данных может исказить результаты анализа. Поэтому, прежде чем удалять выбросы, стоит тщательно анализировать, являются ли эти данные действительно ошибками или аномалиями, которые не соответствуют реальности, или же они отражают важные особенности распределения. В данном случае, если рассмотреть подробней, то редкие аномалии встречаются в высотах потолков и можно обратить внимание на кол-во комнат.
#
# **Во-вторых**, в твоем коде есть небольшая ошибка в логике удаления выбросов. Когда ты определяешь, что процент выбросов больше допустимого, ты пытаешься удалить только ту часть данных, которая не превышает `max_outliers_percentage`. Однако, ты используешь метод `nsmallest` на выбросах, что не совсем корректно, так как ты хочешь удалять самые крайние выбросы, а не наименьшие значения среди выбросов. Более того, логика удаления должна быть направлена на уменьшение влияния выбросов, а не на их полное исключение, если это приводит к потере большого объема данных.
#
# Вот несколько предложений по улучшению:
#
# * Пересмотреть условие для удаления: Вместо удаления фиксированного процента данных, рассмотри возможность адаптации границ для выбросов в зависимости от распределения данных. Это может быть более гибким подходом для уменьшения влияния выбросов.
#
# * Проверка распределения: Прежде чем применять удаление, анализируй распределение значений в столбце. Возможно, выбросы являются частью нормального распределения данных.
#
#
#
# Помни, что любое изменение данных должно быть тщательно обосновано и проверено на влияние на результаты анализа. Это поможет избежать потери важной информации и искажения результатов.
#
# Попробуй, пожалуйста еще раз вглянуть на подход и вернуть данные, иначе нам просто не с чем работать. Напомню, что потерять мы позволить себе можем не более 10% данных.
#
# Буду ждать твой проект на проверку.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.3</b>
#
#  Решил отойти от своей идеи, не получилось ее доработать. Ниже представил другое решение, добавив его в то же место, где гистограммы
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
# Понял тебя
# </div>

# %% [markdown]
# Применяем функцию к каждому столбцу, который нужно проверить

# %% [markdown]
# data = anomaly_clear(data, 'total_area')
# data = anomaly_clear(data, 'living_area')
# data = anomaly_clear(data, 'kitchen_area')
# data = anomaly_clear(data, 'last_price')
# data = anomaly_clear(data, 'rooms')
# data = anomaly_clear(data, 'ceiling_height')
# #data = anomaly_clear(data, 'floors_type')
# data = anomaly_clear(data, 'floors_total')
# data = anomaly_clear(data, 'cityCenters_nearest')
# data = anomaly_clear(data, 'parks_nearest')

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.2</b>
#
#  Я собрал все случаи применения функции в одну ячейку
# </div>

# %%
data.size
# Out:
# 706950

# %%
plt.figure(figsize=(10, 6))
plt.title('Распределение количества комнат в недвижимости')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
#plt.hist(['rooms'], bins=7);
data['rooms'].hist(range=(0,10));

# %% [markdown]
# Количество комнат распределилось в основном от 0 до 4, далее значений намного меньше, что выглядит неестественно, можем установить ограничение от 1 до 4 комнат в квартире.

# %%
data['rooms'] = data.query('(rooms > 0) & (rooms < 5)')['rooms']
data['rooms'].hist();

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на оформление графиков в проекте. Важно, чтобы у каждого графика было название, а оси были четко подписаны. Пожалуйста, пройдись по всем графикам и убедись в их корректном оформлении.
#
# Помни, график — это инструмент общения с заказчиком. Он должен быть ясным, лаконичным и информативным.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#  Согласен, графики подписал, подскажи - что еще можно сделать с ними для наглядности?
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
# Дополнительно можно построить boxplot для нагллядности
# </div>

# %%
plt.title('Общая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Количество объявлений')
data['total_area'].hist(bins=50, range=(0,300));

# %% [markdown]
# Общая площадь распределилась в основном менее 100 кв метров, далее значений намного меньше, что выглядит неестественно

# %%
data['total_area'] = data.query('(total_area > 30) & (total_area < 150)')['total_area']
data['total_area'].hist();

# %%
plt.title('Жилая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Количество объявлений')
data['living_area'].hist(range=(0,250));

# %% [markdown]
# Жилая площадь распределилась в основном между 0 и 80 кв метров, далее значений намного меньше, что выглядит неестественно

# %%
data['living_area'] = data.query('(living_area > 10) & (living_area < 90)')['living_area']
data['living_area'].hist();

# %%
plt.figure(figsize=(10, 6))
plt.title('Площадь кухни')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Количество объявлений')
data['kitchen_area'].hist(bins=20)
print(data['kitchen_area'].sort_values().head(10))
plt.show()
# Out:
# 23060    0.0
# 1778     0.0
# 4868     0.0
# 14450    0.0
# 19371    0.0
# 1783     0.0
# 14452    0.0
# 14455    0.0
# 19368    0.0
# 1787     0.0
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Площадь кухни распределилась в основном между 0 и 20 кв метров, далее значений намного меньше, что выглядит неестественно

# %%
data['kitchen_area'] = data.query('(kitchen_area > 10) & (kitchen_area < 30)')['kitchen_area']
data['kitchen_area'].hist();

# %%
plt.title('Цена на момент публикации')
plt.xlabel('Цена, 10 млн руб.')
plt.ylabel('Количество объявлений')
data['last_price'].hist(range=(0,20000000));

# %%
data['last_price'] = data.query('(last_price > 1000000) & (last_price < 20000000)')['last_price']
data['last_price'].hist();

# %%
data.loc[(data['ceiling_height'] > 14) & (data['ceiling_height'] <= 32), 'ceiling_height'] /= 10

plt.title('Высота потолков')
plt.xlabel('Высота, м')
plt.ylabel('Количество объявлений')
data['ceiling_height'].hist(bins=7, range=(1,6));

# %%
data['ceiling_height'] = data.query('(ceiling_height > 1.7) & (ceiling_height < 3.2)')['ceiling_height']
data['ceiling_height'].hist();

# %%
plt.title('Общее количество этажей в здании')
plt.xlabel('Количество этажей')
plt.ylabel('Количество объявлений')
data['floors_total'].hist();

# %%
data['floors_total'] = data.query('(floors_total > 0) & (floors_total < 25)')['floors_total']
data['floors_total'].hist();

# %%
plt.title('Расстояние до центра города')
plt.xlabel('Расстояние, м')
plt.ylabel('Количество объявлений')
data['cityCenters_nearest'].hist();

# %%
data['cityCenters_nearest'] = data.query('(cityCenters_nearest> 0) & (cityCenters_nearest < 30000)')['cityCenters_nearest']
data['cityCenters_nearest'].hist();

# %%
plt.title('Расстояние до ближайшего парка')
plt.xlabel('Расстояние, м')
plt.ylabel('Количество объявлений')
data['parks_nearest'].hist();

# %%
data['parks_nearest'] = data.query('(parks_nearest > 0) & (parks_nearest < 750)')['parks_nearest']
data['parks_nearest'].hist();

# %%
#print(data['floor_type'].sort_values().unique())
#ВОПРОС РЕВЬЮЕРУ - столбец принимает только 3 значения, в чем необходимость его менять?
# по диаграмме видно, что значений "другой" очень много, но можем ли мы это как то исправить?

plt.title('Распределение квартир по типу этажа')
plt.xlabel('Тип этажа')
plt.ylabel('Количество объявлений')
data['floor_type'].hist();

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# 1) Не понял первый вопрос про "менять".
#
# 2) Исправлять ничего не нужно график четко отображает действительность.
# </div>

# %% [markdown]
# 2 часть

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово',
#        'поселок Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
plt.title('Распределение времени продажи недвижимости')
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
data['days_exposition'].hist(bins=100) # пик у нуля
#data['days_exposition'].sort_values().unique()
print(f'Медиана: {data["days_exposition"].median()} Среднее: {data["days_exposition"].mean()}')
# Out:
# Медиана: <NA> Среднее: <NA>
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * По итогу исследовательской части мы потеряли почти 50% датасета. Стоит проводить фильтрацию аккуратно. Удалять более 10% данных мы не можем. Если выбросы - более 10%, то это уже не выбросы, а наоборот один из трендов. Данные необходимо вернуть.
#
# * Рассмотрены и визуализированы не все параметры из ТЗ.
#
# * Нет выводов о изучении параметров.
#
# Прошу тебя дополнить.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
#
# </div>

# %% [markdown]
# 3 часть

# %% [markdown]
# Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
#
# #Для этого сделаем отдельную сводную таблицу data_svtable только с нужными параметрами.

# %%
#data_svtable = pd.pivot_table(data, index=["last_price"], columns= ['total_area', 'living_area', 'kitchen_area', 'rooms', 'floor_type_digit', 'day_publication', 'month_publication', 'year_publication'], values=['total_area', 'living_area', 'kitchen_area', 'rooms', 'floor_type_digit', 'day_publication', 'month_publication', 'year_publication'])
#data_svtable.head(10)

# %%
factors = ['total_area', 'living_area', 'kitchen_area', 'rooms', 'floor_type_digit', 'day_publication', 'month_publication', 'year_publication'] 
factors_corr = []
for i in factors:
    factors_corr.append("{:.5%}".format(data['last_price'].corr(data[i])))
    print(i,':', factors_corr[-1])
# Out:
# total_area : 75.59983%
# living_area : 64.25821%
# kitchen_area : 39.81230%
# rooms : 46.65276%
# floor_type_digit : 5.50698%
# day_publication : -1.51518%
# month_publication : 0.27158%
# year_publication : -2.33601%

# %% [markdown]
# Из ячейки выше видно, что цена почти **не зависит** от **даты публикации** и **этажа, на котором находится квартира**
#
# Если смотреть зависимость по возрастанию, то остальные показатели выстроятся так:
# 1)Площадь кухни
# 2)Количество комнат
# 3)Жилая площадь
# 4)Общая площадь квартиры

# %%
data.plot(x='last_price', y='total_area', kind='scatter', alpha=0.3) 
data.plot(x='last_price', y='kitchen_area', kind='scatter', alpha=0.3) 
data.plot(x='last_price', y='living_area', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='last_price', ylabel='living_area'>

# %%
data.pivot_table(index='rooms',values='last_price').plot(y='last_price', kind='bar');

# %%
data.pivot_table(index='month_publication',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean')
data.pivot_table(index='month_publication',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median')
# Out:
# <AxesSubplot:title={'center':'median'}, xlabel='month_publication'>

# %%
data.pivot_table(index='day_publication',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean');
data.pivot_table(index='day_publication',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median');

# %%
data.pivot_table(index='year_publication',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean');
data.pivot_table(index='year_publication',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median');

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# На рассмотренных выше параметров коэффициент корреляции Пирсона работал хорошо. Но применение его к остальным параметрам - типу этажа, дню недели, году, и месяцу - не эффективно, т.к. цена квартиры зависит от них не линейно.
# </div>

# %% [markdown]
# <h4>Средняя цена одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %%
localities_10 = data.pivot_table(index='locality_name', values='square_meter_price', aggfunc=['count', 'mean'])
localities_10.columns = ['count', 'mean']
localities_10 = localities_10.sort_values('count', ascending = False).iloc[:10]


localities_10
data[data['square_meter_price'].isna() == False]
localities_10.size
data['locality_name'].unique()
localities_10
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    15651  114868.877339
# поселок Мурино       552   85629.568641
# поселок Шушары       439   78551.344647
# Всеволожск           398   68654.473970
# Пушкин               369  103125.819377
# Колпино              338   75424.579112
# поселок Парголово    327   90175.913089
# Гатчина              307   68746.146515
# деревня Кудрово      299   92473.547559
# Выборг               237   58141.909325

# %%
localities_10.sort_values('mean', ascending=False)
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    15651  114868.877339
# Пушкин               369  103125.819377
# деревня Кудрово      299   92473.547559
# поселок Парголово    327   90175.913089
# поселок Мурино       552   85629.568641
# поселок Шушары       439   78551.344647
# Колпино              338   75424.579112
# Гатчина              307   68746.146515
# Всеволожск           398   68654.473970
# Выборг               237   58141.909325

# %% [markdown]
# После корректировки подхода к расчету цены за квадратный метр с использованием 'last_price' и 'total_area', нам удалось создать сводную таблицу для 10 населенных пунктов с наибольшим количеством объявлений. Вот основные выводы:
#
# Топ-10 населенных пунктов по количеству объявлений:
#
# Санкт-Петербург лидирует с значительным отрывом, имея 15,721 объявлений, за ним следуют гораздо меньшие населенные пункты, такие как Мурино и Шушары.
# Средняя цена за квадратный метр наивысшая в Санкт-Петербурге, около 114,849 рублей, и наименьшая в Выборге, примерно 58,142 рубля.
# Анализ цены за квадратный метр:
#
# При сортировке по средней цене за квадратный метр Санкт-Петербург остается самым дорогим населенным пунктом, что указывает на то, что не только количество объявлений здесь наибольшее, но и цены в среднем выше.
# Пушкин и Кудрово также имеют высокие средние цены, что говорит о том, что эти районы являются более премиальными.
# На нижнем конце шкалы Выборг показывает самую низкую среднюю цену за квадратный метр среди топ-10 населенных пунктов, что может сделать его привлекательным вариантом для покупателей с ограниченным бюджетом.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Здесь стоит еще раз взглянуть на результат после возвращения данных. Также не хватает вывода.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
#  Исправил, должно работать
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
# Да, теперь верно
# </div>

# %% [markdown]
# Cамая высокая стоимость

# %%
localities_10[localities_10['mean']==localities_10['mean'].max()]
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15651  114868.877339

# %% [markdown]
# Cамая низкая стоимость

# %%
localities_10[localities_10['mean']==localities_10['mean'].min()]
# Out:
#                count          mean
# locality_name
# Выборг           237  58141.909325

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению здесь код упал с ошибкой.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
#
# </div>

# %% [markdown]
# <h4>Вычисление средней стоимости квартир Санкт-Петербурга на разном удалении от центра

# %% [markdown]
# Выделение квартир в Санкт-Петербурге

# %%
spb_data = data[data['locality_name'] == 'Санкт-Петербург']

# %% [markdown]
# Расчет средней цены за каждый километр

# %%
price_per_km = spb_data.pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='mean')

# %% [markdown]
# Построение графика изменения средней цены от расстояния до центра

# %%
plt.figure(figsize=(10, 6))
plt.plot(price_per_km.index, price_per_km['last_price'], marker='o')
plt.title('Средняя цена квартир в Санкт-Петербурге в зависимости от расстояния до центра')
plt.xlabel('Расстояние до центра (км)')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# На графике показана средняя цена квартир в Санкт-Петербурге в зависимости от расстояния до центра города. Из графика видно, что с увеличением расстояния от центра средняя стоимость квартир, в общем, снижается.
# Особенно заметен спад цен на расстоянии до 10 километров от центра, после чего цены стабилизируются и изменяются менее значительно.
#
# Это наблюдение подтверждает общее представление о том, что недвижимость в центре Санкт-Петербурга является более дорогой по сравнению с районами, расположенными дальше от центра. В центральных районах цены выше из-за близости к историческим, культурным и административным объектам, а также из-за развитой инфраструктуры и транспортной доступности.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Отсутствует очень важная часть исследования - общий вывод о проделанной работе в проекте. Для большей наглядности для заказчика предлагаю структурировать итоговые выводы, выделяя ключевые аспекты работы. В финальном разделе стоит максимально детализировать и обогатить информацией с конкретными цифрами все найденные закономерности и особенности в данных в ходе исследования.
#
# Давай сделаем обзорную часть более развернутой, чтобы подчеркнуть качество проведенной работы и предоставить заказчику полное понимание проведенного анализа.
# </div>

# %% [markdown]
# Общий вывод:

# %% [markdown]
# В рамках проекта была поставлена задача анализа рынка недвижимости на основе данных объявлений о продаже жилья. Целью исследования являлось выявление ключевых факторов, влияющих на стоимость недвижимости, а также анализ временных рамок продажи объектов.
#
# Исследование включало в себя этапы предобработки данных, такие как обработка пропущенных значений, преобразование типов данных и удаление выбросов. Для анализа данных использовались методы описательной статистики, корреляционного анализа и визуализации.
#
# **Основные результаты:**
# Было обнаружено, что общая площадь, количество комнат и расположение являются определяющими факторами цены недвижимости.
# Расстояние до центра города значительно влияет на стоимость, при этом цены значительно снижаются с увеличением удаленности от центра.
# Среднее время продажи недвижимости составляет около 180 дней, при этом существуют как быстрые продажи (менее 30 дней), так и длительные (более 200 дней), что может указывать на различия в цене, качестве и местоположении объектов.
#
# **Закономерности и особенности в данных:**
# Выявлено, что высота потолков и наличие балкона также оказывают влияние на стоимость объектов недвижимости. Объекты с высокими потолками и балконами ценятся выше.
# Анализ распределения цен показал, что средняя цена квадратного метра наиболее высока в центре города и плавно снижается по мере удаления от центра.
# Были идентифицированы районы с наибольшей и наименьшей стоимостью жилья, что может служить полезным инструментом для потенциальных инвесторов и покупателей.
#
# **Заключение:**
# Проведенный анализ рынка недвижимости позволил не только выявить ключевые факторы, влияющие на цены на жилье, но и определить типичные сроки продажи объектов. Результаты исследования могут быть использованы для разработки стратегий ценообразования, а также для предоставления рекомендаций покупателям и продавцам недвижимости.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.4</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:
#
# * [Как строить красивые графики на Python с Seaborn](https://habr.com/ru/companies/otus/articles/540526/)
#
# * [Seaborn для визуализации данных в Python](https://pythonru.com/biblioteki/seaborn-plot)
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Николай, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Николай, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [ ]  Найдены пропущенные значения.
# - [ ]  Пропущенные значения заполнены там, где это возможно.
# - [ ]  Объяснено, какие пропущенные значения обнаружены.
# - [ ]  В каждом столбце установлен корректный тип данных.
# - [ ]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [ ]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [ ]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [ ]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [ ]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [ ]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [ ]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [ ]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [ ]  На каждом этапе сделаны промежуточные выводы.
# - [ ]  В конце проекта сделан общий вывод.
